# %% [markdown]
# <a href="https://colab.research.google.com/github/smmurdock/DC-intro-to-regression-with-statsmodel/blob/main/intro_to_regression_with_statsmodels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Regression with statsmodels in Python

# %% [markdown]
# ## Libraries & Data

# %%
cd /content/drive/MyDrive/1 Projects/DC_intro_to_regression_with_statsmodels/datasets
# Out:
# /content/drive/MyDrive/1 Projects/DC_intro_to_regression_with_statsmodels/datasets

# %%
import pandas as pd
import numpy as np

ad_conversion = pd.read_csv('ad_conversion.csv')
ad_conversion.head()
# Out:
#    spent_usd  n_impressions  n_clicks
# 0       1.43           7350         1
# 1       1.82          17861         2
# 2       1.25           4259         1
# 3       1.29           4133         1
# 4       4.77          15615         3

# %% [markdown]
# ## Simple Linear Regression Modeling
